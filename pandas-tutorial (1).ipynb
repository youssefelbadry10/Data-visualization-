# %%
import pandas as pd

# %%
df = pd.read_csv('/kaggle/input/students-performance-in-exams/StudentsPerformance.csv')

# %%
#show the table (columns and rows)
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
#show the last five rows 
df.tail()
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86

# %%
#show all information about your data 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
#number of unique value in each column 
df.nunique()
# Out:
# gender                          2
# race/ethnicity                  5
# parental level of education     6
# lunch                           2
# test preparation course         2
# math score                     81
# reading score                  72
# writing score                  77
# dtype: int64

# %%
#describe each coulmn 
df.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
#show the counts of each unique value in the column 
df['gender'].value_counts()
# Out:
# gender
# female    518
# male      482
# Name: count, dtype: int64

# %%
df['race/ethnicity'].value_counts()
# Out:
# race/ethnicity
# group C    319
# group D    262
# group B    190
# group E    140
# group A     89
# Name: count, dtype: int64

# %%
#numbers of gender in each (race/ethnicity)
df.groupby('race/ethnicity')['gender'].value_counts()
# Out:
# race/ethnicity  gender
# group A         male       53
#                 female     36
# group B         female    104
#                 male       86
# group C         female    180
#                 male      139
# group D         male      133
#                 female    129
# group E         male       71
#                 female     69
# Name: count, dtype: int64

# %%
df['math score'].describe()
# Out:
# count    1000.00000
# mean       66.08900
# std        15.16308
# min         0.00000
# 25%        57.00000
# 50%        66.00000
# 75%        77.00000
# max       100.00000
# Name: math score, dtype: float64

# %%
# condition to know who get zero in math 
df[df['math score'] == 0 ]
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 59  female        group C            some high school  free/reduced
#
#    test preparation course  math score  reading score  writing score
# 59                    none           0             17             10

# %%
# the top 10 values were repeated in (math score)
df['math score'].value_counts().head(10)
# Out:
# math score
# 65    36
# 62    35
# 69    32
# 59    32
# 61    27
# 73    27
# 63    26
# 67    26
# 68    26
# 71    26
# Name: count, dtype: int64

# %%
df[df['math score'] == 100]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 149    male        group E          associate's degree  free/reduced
# 451  female        group E                some college      standard
# 458  female        group E           bachelor's degree      standard
# 623    male        group A                some college      standard
# 625    male        group D                some college      standard
# 916    male        group E           bachelor's degree      standard
# 962  female        group E          associate's degree      standard
#
#     test preparation course  math score  reading score  writing score
# 149               completed         100            100             93
# 451                    none         100             92             97
# 458                    none         100            100            100
# 623               completed         100             96             86
# ...

# %%
df[df['math score'] < 50 ][df['gender'] == 'female']['math score'].count()
# Out:
# /tmp/ipykernel_33/2720449507.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df[df['math score'] < 50 ][df['gender'] == 'female']['math score'].count()
# 86

# %%
df[df['math score'] < 50 ][df['race/ethnicity'] == 'group E']
# Out:
# /tmp/ipykernel_33/2985580344.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df[df['math score'] < 50 ][df['race/ethnicity'] == 'group E']
#      gender race/ethnicity parental level of education         lunch  \
# 76     male        group E            some high school      standard
# 142  female        group E                some college  free/reduced
# 225  female        group E             master's degree  free/reduced
# 375    male        group E          associate's degree  free/reduced
# 383  female        group E            some high school  free/reduced
# 616  female        group E           bachelor's degree      standard
# 807  female        group E                 high school  free/reduced
# 822    male        group E                some college  free/reduced
# 895  female        group E            some high school  free/reduced
# 928    male        group E          associate's degree  free/reduced
#
# ...

# %%
df.groupby('gender')['math score'].value_counts()
# Out:
# gender  math score
# female  65            28
#         59            21
#         77            16
#         69            16
#         67            16
#                       ..
# male    27             1
#         28             1
#         35             1
#         36             1
#         37             1
# Name: count, Length: 147, dtype: int64

# %%
falling = df[df['math score'] < 50 ]
falling.groupby('gender')['math score'].value_counts()
# Out:
# gender  math score
# female  49            8
#         48            7
#         47            6
#         44            6
#         45            5
#         42            5
#         40            5
#         46            5
#         43            4
#         41            4
#         35            4
#         38            3
#         32            3
#         29            3
#         37            3
#         39            2
#         34            2
#         18            1
#         24            1
#         23            1
#         19            1
#         22            1
#         26            1
#         8             1
#         36            1
#         33            1
#         27            1
#         0             1
# male    49            9
#         46            6
#         40            5
#         47            5
#         45            4
#         48            4
#         44            3
#         41            2
#         30            2
# ...

# %%
# Ascending is the type of sort 
falling.groupby('parental level of education')['math score'].count().sort_values(ascending= False )
# Out:
# parental level of education
# some high school      36
# high school           33
# associate's degree    27
# some college          22
# bachelor's degree     11
# master's degree        6
# Name: math score, dtype: int64

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.gender.value_counts()
# Out:
# gender
# female    518
# male      482
# Name: count, dtype: int64

# %%
for i in df['reading score']:
    if i < 50 :
        print(i)
# Out:
# 43
# 32
# 42
# 42
# 44
# 41
# 17
# 39
# 37
# 49
# 41
# 26
# 49
# 45
# 47
# 39
# 34
# 45
# 44
# 49
# 37
# 43
# 39
# 49
# 41
# 28
# 42
# 43
# 49
# 42
# 49
# 48
# 46
# 41
# 46
# 46
# 23
# 37
# 38
# 34
# 43
# 49
# 43
# 45
# 43
# 39
# 48
# 46
# 31
# 47
# 48
# 49
# 49
# 41
# 48
# 45
# 39
# 43
# 48
# 24
# 29
# 45
# 48
# 40
# 34
# 48
# 43
# 39
# 46
# 47
# 48
# 44
# 38
# 45
# 31
# 47
# 44
# 49
# 42
# 42
# 46
# 34
# 29
# 48
# 48
# 42
# 43
# 41
# 24
# 45

# %%
len(df[df.gender == "male"])
# Out:
# 482

# %%
df[(df["math score"] == 100)&(df["reading score"] == 100 ) & (df["writing score"] == 100 )]
# Out:
#      gender race/ethnicity parental level of education     lunch  \
# 458  female        group E           bachelor's degree  standard
# 916    male        group E           bachelor's degree  standard
# 962  female        group E          associate's degree  standard
#
#     test preparation course  math score  reading score  writing score
# 458                    none         100            100            100
# 916               completed         100            100            100
# 962                    none         100            100            100

# %%
df[(df["math score"] == 100)| (df["reading score"] == 100 )]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 106  female        group D             master's degree      standard
# 114  female        group E           bachelor's degree      standard
# 149    male        group E          associate's degree  free/reduced
# 165  female        group C           bachelor's degree      standard
# 179  female        group D            some high school      standard
# 381    male        group C          associate's degree      standard
# 451  female        group E                some college      standard
# 458  female        group E           bachelor's degree      standard
# 546  female        group A            some high school      standard
# 566  female        group E           bachelor's degree  free/reduced
# 594  female        group C           bachelor's degree      standard
# 623    male        group A                some college      standard
# 625    male        group D                some college      standard
# ...

# %%
df[(df["math score"] == 100)| (df["reading score"] == 100 )][['writing score']]
# Out:
#      writing score
# 106            100
# 114            100
# 149             93
# 165            100
# 179            100
# 381             95
# 451             97
# 458            100
# 546             97
# 566            100
# 594             99
# 623             86
# 625             99
# 712             99
# 886             95
# 903            100
# 916            100
# 957            100
# 962            100
# 970            100

# %%
#iloc[: , :-1] to show all columns except the last one 
df[(df["math score"] == 100)| (df["reading score"] == 100 )].iloc[: , :-1]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 106  female        group D             master's degree      standard
# 114  female        group E           bachelor's degree      standard
# 149    male        group E          associate's degree  free/reduced
# 165  female        group C           bachelor's degree      standard
# 179  female        group D            some high school      standard
# 381    male        group C          associate's degree      standard
# 451  female        group E                some college      standard
# 458  female        group E           bachelor's degree      standard
# 546  female        group A            some high school      standard
# 566  female        group E           bachelor's degree  free/reduced
# 594  female        group C           bachelor's degree      standard
# 623    male        group A                some college      standard
# 625    male        group D                some college      standard
# ...

# %%
df['gender'] [df['math score'] == df['math score'].min()]
# Out:
# 59    female
# Name: gender, dtype: object

# %%
df['math score'][59]
# Out:
# 0

# %%
#idmax to get the index of the most repeated value 
df['math score'].value_counts().idxmax()
# Out:
# 65

# %%
#max to get the ranking of person 
df['math score'].value_counts().max()
# Out:
# 36

# %%
# this made the main column is (math score )
df.set_index('math score', inplace= True )
df
# Out:
#             gender race/ethnicity parental level of education         lunch  \
# math score
# 72          female        group B           bachelor's degree      standard
# 69          female        group C                some college      standard
# 90          female        group B             master's degree      standard
# 47            male        group A          associate's degree  free/reduced
# 76            male        group C                some college      standard
# ...            ...            ...                         ...           ...
# 88          female        group E             master's degree      standard
# 62            male        group C                 high school  free/reduced
# 59          female        group C                 high school  free/reduced
# 68          female        group D                some college      standard
# 77          female        group D                some college  free/reduced
#
# ...

# %%
df.loc[56]
# Out:
#             gender race/ethnicity parental level of education         lunch  \
# math score
# 56          female        group E             master's degree  free/reduced
# 56          female        group D                 high school      standard
# 56          female        group D                 high school      standard
# 56            male        group D            some high school  free/reduced
# 56          female        group D          associate's degree  free/reduced
# 56            male        group C            some high school  free/reduced
# 56          female        group C           bachelor's degree      standard
# 56          female        group C          associate's degree  free/reduced
# 56          female        group A                some college      standard
#
#            test preparation course  reading score  writing score
# math score
# 56                            none             72             65
# ...

# %%
#get it back 
df.reset_index(inplace = True)

# %%
#to make another column that you can check any thing 
my_list= []
for i in df['test preparation course']:
    if i == 'completed' :
        my_list.append(True)
        
    else:
        my_list.append(False)
df['check'] = my_list
df
# Out:
#      math score  gender race/ethnicity parental level of education  \
# 0            72  female        group B           bachelor's degree
# 1            69  female        group C                some college
# 2            90  female        group B             master's degree
# 3            47    male        group A          associate's degree
# 4            76    male        group C                some college
# ..          ...     ...            ...                         ...
# 995          88  female        group E             master's degree
# 996          62    male        group C                 high school
# 997          59  female        group C                 high school
# 998          68  female        group D                some college
# 999          77  female        group D                some college
#
#             lunch test preparation course  reading score  writing score  check
# 0        standard                    none             72             74  False
# ...

# %%
df.reset_index(inplace= True)

# %%
#to delete column 
df.drop("writing score", inplace= True, axis= 1 )
df
# Out:
#      index  math score  gender race/ethnicity parental level of education  \
# 0        0          72  female        group B           bachelor's degree
# 1        1          69  female        group C                some college
# 2        2          90  female        group B             master's degree
# 3        3          47    male        group A          associate's degree
# 4        4          76    male        group C                some college
# ..     ...         ...     ...            ...                         ...
# 995    995          88  female        group E             master's degree
# 996    996          62    male        group C                 high school
# 997    997          59  female        group C                 high school
# 998    998          68  female        group D                some college
# 999    999          77  female        group D                some college
#
#             lunch test preparation course  reading score  check
# ...

# %%
#to delete row 
df.drop(999 , inplace= True, axis= 0 )
df
# Out:
#      index  math score  gender race/ethnicity parental level of education  \
# 0        0          72  female        group B           bachelor's degree
# 1        1          69  female        group C                some college
# 2        2          90  female        group B             master's degree
# 3        3          47    male        group A          associate's degree
# 4        4          76    male        group C                some college
# ..     ...         ...     ...            ...                         ...
# 994    994          63    male        group A                 high school
# 995    995          88  female        group E             master's degree
# 996    996          62    male        group C                 high school
# 997    997          59  female        group C                 high school
# 998    998          68  female        group D                some college
#
#             lunch test preparation course  reading score  check
# ...

# %%
#to change names of coulmns 
df = pd.read_csv("/kaggle/input/students-performance-in-exams/StudentsPerformance.csv", header=None, names = ["col1","col2","col3","col4","col5","col6","col7","col8"])
df
# Out:
#         col1            col2                         col3          col4  \
# 0     gender  race/ethnicity  parental level of education         lunch
# 1     female         group B            bachelor's degree      standard
# 2     female         group C                 some college      standard
# 3     female         group B              master's degree      standard
# 4       male         group A           associate's degree  free/reduced
# ...      ...             ...                          ...           ...
# 996   female         group E              master's degree      standard
# 997     male         group C                  high school  free/reduced
# 998   female         group C                  high school  free/reduced
# 999   female         group D                 some college      standard
# 1000  female         group D                 some college  free/reduced
#
#                          col5        col6           col7           col8
# ...

# %%
#to read a specific number pf rows
df = pd.read_csv("/kaggle/input/students-performance-in-exams/StudentsPerformance.csv",  nrows=2)
df
# Out:
#    gender race/ethnicity parental level of education     lunch  \
# 0  female        group B           bachelor's degree  standard
# 1  female        group C                some college  standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88

# %%
#to replce any value 
df = pd.read_csv("/kaggle/input/students-performance-in-exams/StudentsPerformance.csv")
new_df = df.replace({'race/ethnicity': 'group E'},'Africian peaple', regex=True) 
new_df
# Out:
#      gender   race/ethnicity parental level of education         lunch  \
# 0    female          group B           bachelor's degree      standard
# 1    female          group C                some college      standard
# 2    female          group B             master's degree      standard
# 3      male          group A          associate's degree  free/reduced
# 4      male          group C                some college      standard
# ..      ...              ...                         ...           ...
# 995  female  Africian peaple             master's degree      standard
# 996    male          group C                 high school  free/reduced
# 997  female          group C                 high school  free/reduced
# 998  female          group D                some college      standard
# 999  female          group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...
